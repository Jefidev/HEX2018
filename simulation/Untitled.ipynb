# %%
import math

route_1 = {
    
    'duration' : 40,
    
    'timeslots' : {
    
        1 : {
            'time_start' : 0,
            'time_end': 239,
            'frequency' : 10,
            'people' : 2000
            
        },
        
        2 : {
            'time_start' : 240,
            'time_end': 599,
            'frequency' : 10,
            'people' : 800
        },
        
        3 : {
            'time_start' : 600,
            'time_end': 839,
            'frequency' : 10,
            'people' : 2000
        },
        
        4 : {
            'time_start' : 840,
            'time_end': 1199,
            'frequency' : 5,
            'people' : 4000
        }
    
    }
    
}

# %%
def findCurrentTimeSlot(time):
    if time > 240: return 1
    elif time > 600: return 2
    elif time > 840: return 3
    elif time > 1200: return 4
    else: return 0

class Route: 
    
    def __init__(self, id, duration, time = 0, timeslots = None, frequency = 10, people = 800):
        if time == 0: self.current_timeslot = 1
        else: self.current_timeslot = findCurrentTimeSlot(time)
        self.timeslots = timeslots
        self.id = id
        self.duration = duration
        self.last_start = -1000
        self.frequency = frequency
        self.people = people
        
    
    def setTimesplots(self, timeslots):
        self.timeslots = timeslots
        
    def update(self, time):
        
        # update the time
        if (time >= self.timeslots[self.current_timeslot]['time_end']):
            self.current_timeslot += 1
        if self.current_timeslot == 5 : self.current_timeslot = 1 
          
        # update data
        self.frequency = self.timeslots[self.current_timeslot]['frequency']
        self.people = self.timeslots[self.current_timeslot]['people']
            
    def shouldStart(self, time):
        return time - self.last_start >= self.frequency

# %%
class Bus: 
    
    def __init__ (self, id, capacity = 20, battery = None, route = None):
        self.id = id
        self.battery = battery
        self.current_route = route
        self.remaining_time = 0
        self.isRiding = False
        self.capacity = capacity
    
        
        
    def update(self):
        
        if not self.isRiding :
            print ("Bus " + str(self.id)+ " waiting at the station")
            return
        
        self.remaining_time -= 1
        self.battery.use(self.id)
        
        print ("Bus " + str(self.id)+ " have still " + str(self.remaining_time) + " minutes to drive")
        if self.remaining_time == 0:
            print ("Bus " + str(self.id) + " is done, it is now at the station")
            self.done()
        
    def start(self, route, time):
        self.current_route = route
        self.remaining_time = route.duration
        self.isRiding = True
        station.leave(self)
        route.last_start = time
        
    def done(self):
        self.current_route = None
        self.isRiding = False
        station.add(self)
        
    def canTakeRoute(self, route):
        return (route.duration <= self.battery.power)

# %%
class Station:
    
    def __init__(self, buses = [], routes = []):
        self.buses = buses
        self.routes = routes
    
    def add(self, bus):
        self.buses.append(bus)
        
    def leave(self, bus):
        # it's done with pop in update
        # self.buses.remove(bus)
        pass
        
    def update(self, time):
        
        # routes dispatching
        for r in self.routes:
            
            if r.shouldStart(time):
                if (self.buses):
                    for b in self.buses:
                        if (b.canTakeRoute(r)):
                            self.buses.remove(b)
                            b.start(r, time)
                            print("Bus " + str(b.id) + " starts route " + str(r.id) )
                            break
                else:
                    print("Not enough buses at the station or with enough battery...")
        
        # Battery management
        
        for b in self.buses:                   
            # Charged
            if (b.battery.power >= b.battery.max_power):
                b.battery.power = b.battery.max_power
            else:
                # Charging
                b.battery.power += 0.017 * b.battery.max_power
                print("Bus " + str(b.id) + " fastly charging => " + str(math.floor(b.battery.power)) + "/" + str(b.battery.max_power))

# %%
class Battery:
    
    def __init__ (self, max_power, cost = 0):
        self.max_power = max_power
        self.power = max_power
        self.cost = cost
        self.nb_recharges = 0
        
    def charge (self, power): 
        self.power += power
        if (self.max_power < self.power):
            self.power = self.max_power
            
    def use(self, id):
        self.power -= 1
        print("Battery from bus " + str(id) + " has " + str(math.floor(self.power)) + " units of power left")
        if (self.power <= 0):
            print("FAIL!!! Bus ran out of energy while using")
            self.power = 0

# %%
class Charger : pass

# Fast chargin : 1h and 1h30
# one a minute basis, 1 tick is 1.7% && 1.1%

# Slow chargin : 

class FastCharger(Charger):
    
    def __init__ (self):
        self.current_bus = None
    
    def charge(self, bus):
        self.current_bus = bus
        
    def stopCharging(self):
        self.current_bus = None
        
    def update(self):
        if (self.current_bus):
            self.current_bus.battery.charge(1.7 * self.current_bus.battery.max_power)

# %%
class World: 
    
    def __init__ (self) : 
        self.time = 0
        self.chargers = [];
        self.buses = [];
        self.routes = [];
    
    def tick(self):
        
        self.time += 1
        
        print ("Time is now " + str(self.time))
        
        if (self.time >= 1200):
            self.time = 0
            
        for charger in self.chargers:
            charger.update()
        
        for bus in self.buses:
            bus.update()
            
        for route in self.routes:
            route.update(self.time)
            
        station.update(self.time)

# %%
r1 = Route(1, duration = 40, timeslots = route_1['timeslots'])
r2 = Route(2, duration = 60, timeslots = route_1['timeslots'])
r3 = Route(3, duration = 110, timeslots = route_1['timeslots'])

bt1 = Battery(130)
bt2 = Battery(80)
bt3 = Battery(100)
bt4 = Battery(100)
bt5 = Battery(100)
bt6 = Battery(100)
bt7 = Battery(100)
bt8 = Battery(100)

b1 = Bus(1, 20, bt1, r1)
b2 = Bus(2, 30, bt2, r1)
b3 = Bus(3, 50, bt3, r1)
b4 = Bus(4, 20, bt4, r1)
b5 = Bus(5, 20, bt5, r1)
b6 = Bus(6, 30, bt6, r1)
b7 = Bus(7, 50, bt7, r1)
b8 = Bus(8, 20, bt8, r1)

buses = [b1, b2, b3, b4, b5, b6, b7, b8]
routes = sorted([r1, r2, r3], key=lambda route: route.duration)[::-1]

station = Station(buses, routes)

# %%
w = World()

# %%
w.buses.extend(buses)
w.routes.extend(routes)

# %%
for i in range(300) : w.tick()
# Out:
# Time is now 1
# Bus 1 waiting at the station
# Bus 2 waiting at the station
# Bus 3 waiting at the station
# Bus 4 waiting at the station
# Bus 5 waiting at the station
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Bus 1 starts route 3
# Bus 2 starts route 2
# Bus 3 starts route 1
# Time is now 2
# Battery from bus 1 has 129 units of power left
# Bus 1 have still 109 minutes to drive
# Battery from bus 2 has 99 units of power left
# Bus 2 have still 59 minutes to drive
# Battery from bus 3 has 99 units of power left
# Bus 3 have still 39 minutes to drive
# Bus 4 waiting at the station
# Bus 5 waiting at the station
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 3
# Battery from bus 1 has 128 units of power left
# Bus 1 have still 108 minutes to drive
# Battery from bus 2 has 98 units of power left
# Bus 2 have still 58 minutes to drive
# Battery from bus 3 has 98 units of power left
# Bus 3 have still 38 minutes to drive
# Bus 4 waiting at the station
# Bus 5 waiting at the station
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 4
# Battery from bus 1 has 127 units of power left
# Bus 1 have still 107 minutes to drive
# Battery from bus 2 has 97 units of power left
# Bus 2 have still 57 minutes to drive
# Battery from bus 3 has 97 units of power left
# Bus 3 have still 37 minutes to drive
# Bus 4 waiting at the station
# Bus 5 waiting at the station
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 5
# Battery from bus 1 has 126 units of power left
# Bus 1 have still 106 minutes to drive
# Battery from bus 2 has 96 units of power left
# Bus 2 have still 56 minutes to drive
# Battery from bus 3 has 96 units of power left
# Bus 3 have still 36 minutes to drive
# Bus 4 waiting at the station
# Bus 5 waiting at the station
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 6
# Battery from bus 1 has 125 units of power left
# Bus 1 have still 105 minutes to drive
# Battery from bus 2 has 95 units of power left
# Bus 2 have still 55 minutes to drive
# Battery from bus 3 has 95 units of power left
# Bus 3 have still 35 minutes to drive
# Bus 4 waiting at the station
# Bus 5 waiting at the station
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 7
# Battery from bus 1 has 124 units of power left
# Bus 1 have still 104 minutes to drive
# Battery from bus 2 has 94 units of power left
# Bus 2 have still 54 minutes to drive
# Battery from bus 3 has 94 units of power left
# Bus 3 have still 34 minutes to drive
# Bus 4 waiting at the station
# Bus 5 waiting at the station
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 8
# Battery from bus 1 has 123 units of power left
# Bus 1 have still 103 minutes to drive
# Battery from bus 2 has 93 units of power left
# Bus 2 have still 53 minutes to drive
# Battery from bus 3 has 93 units of power left
# Bus 3 have still 33 minutes to drive
# Bus 4 waiting at the station
# Bus 5 waiting at the station
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 9
# Battery from bus 1 has 122 units of power left
# Bus 1 have still 102 minutes to drive
# Battery from bus 2 has 92 units of power left
# Bus 2 have still 52 minutes to drive
# Battery from bus 3 has 92 units of power left
# Bus 3 have still 32 minutes to drive
# Bus 4 waiting at the station
# Bus 5 waiting at the station
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 10
# Battery from bus 1 has 121 units of power left
# Bus 1 have still 101 minutes to drive
# Battery from bus 2 has 91 units of power left
# Bus 2 have still 51 minutes to drive
# Battery from bus 3 has 91 units of power left
# Bus 3 have still 31 minutes to drive
# Bus 4 waiting at the station
# Bus 5 waiting at the station
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 11
# Battery from bus 1 has 120 units of power left
# Bus 1 have still 100 minutes to drive
# Battery from bus 2 has 90 units of power left
# Bus 2 have still 50 minutes to drive
# Battery from bus 3 has 90 units of power left
# Bus 3 have still 30 minutes to drive
# Bus 4 waiting at the station
# Bus 5 waiting at the station
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Bus 4 starts route 2
# Bus 5 starts route 1
# Time is now 12
# Battery from bus 1 has 119 units of power left
# Bus 1 have still 99 minutes to drive
# Battery from bus 2 has 89 units of power left
# Bus 2 have still 49 minutes to drive
# Battery from bus 3 has 89 units of power left
# Bus 3 have still 29 minutes to drive
# Battery from bus 4 has 99 units of power left
# Bus 4 have still 59 minutes to drive
# Battery from bus 5 has 99 units of power left
# Bus 5 have still 39 minutes to drive
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 13
# Battery from bus 1 has 118 units of power left
# Bus 1 have still 98 minutes to drive
# Battery from bus 2 has 88 units of power left
# Bus 2 have still 48 minutes to drive
# Battery from bus 3 has 88 units of power left
# Bus 3 have still 28 minutes to drive
# Battery from bus 4 has 98 units of power left
# Bus 4 have still 58 minutes to drive
# Battery from bus 5 has 98 units of power left
# Bus 5 have still 38 minutes to drive
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 14
# Battery from bus 1 has 117 units of power left
# Bus 1 have still 97 minutes to drive
# Battery from bus 2 has 87 units of power left
# Bus 2 have still 47 minutes to drive
# Battery from bus 3 has 87 units of power left
# Bus 3 have still 27 minutes to drive
# Battery from bus 4 has 97 units of power left
# Bus 4 have still 57 minutes to drive
# Battery from bus 5 has 97 units of power left
# Bus 5 have still 37 minutes to drive
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 15
# Battery from bus 1 has 116 units of power left
# Bus 1 have still 96 minutes to drive
# Battery from bus 2 has 86 units of power left
# Bus 2 have still 46 minutes to drive
# Battery from bus 3 has 86 units of power left
# Bus 3 have still 26 minutes to drive
# Battery from bus 4 has 96 units of power left
# Bus 4 have still 56 minutes to drive
# Battery from bus 5 has 96 units of power left
# Bus 5 have still 36 minutes to drive
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 16
# Battery from bus 1 has 115 units of power left
# Bus 1 have still 95 minutes to drive
# Battery from bus 2 has 85 units of power left
# Bus 2 have still 45 minutes to drive
# Battery from bus 3 has 85 units of power left
# Bus 3 have still 25 minutes to drive
# Battery from bus 4 has 95 units of power left
# Bus 4 have still 55 minutes to drive
# Battery from bus 5 has 95 units of power left
# Bus 5 have still 35 minutes to drive
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 17
# Battery from bus 1 has 114 units of power left
# Bus 1 have still 94 minutes to drive
# Battery from bus 2 has 84 units of power left
# Bus 2 have still 44 minutes to drive
# Battery from bus 3 has 84 units of power left
# Bus 3 have still 24 minutes to drive
# Battery from bus 4 has 94 units of power left
# Bus 4 have still 54 minutes to drive
# Battery from bus 5 has 94 units of power left
# Bus 5 have still 34 minutes to drive
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 18
# Battery from bus 1 has 113 units of power left
# Bus 1 have still 93 minutes to drive
# Battery from bus 2 has 83 units of power left
# Bus 2 have still 43 minutes to drive
# Battery from bus 3 has 83 units of power left
# Bus 3 have still 23 minutes to drive
# Battery from bus 4 has 93 units of power left
# Bus 4 have still 53 minutes to drive
# Battery from bus 5 has 93 units of power left
# Bus 5 have still 33 minutes to drive
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 19
# Battery from bus 1 has 112 units of power left
# Bus 1 have still 92 minutes to drive
# Battery from bus 2 has 82 units of power left
# Bus 2 have still 42 minutes to drive
# Battery from bus 3 has 82 units of power left
# Bus 3 have still 22 minutes to drive
# Battery from bus 4 has 92 units of power left
# Bus 4 have still 52 minutes to drive
# Battery from bus 5 has 92 units of power left
# Bus 5 have still 32 minutes to drive
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 20
# Battery from bus 1 has 111 units of power left
# Bus 1 have still 91 minutes to drive
# Battery from bus 2 has 81 units of power left
# Bus 2 have still 41 minutes to drive
# Battery from bus 3 has 81 units of power left
# Bus 3 have still 21 minutes to drive
# Battery from bus 4 has 91 units of power left
# Bus 4 have still 51 minutes to drive
# Battery from bus 5 has 91 units of power left
# Bus 5 have still 31 minutes to drive
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Time is now 21
# Battery from bus 1 has 110 units of power left
# Bus 1 have still 90 minutes to drive
# Battery from bus 2 has 80 units of power left
# Bus 2 have still 40 minutes to drive
# Battery from bus 3 has 80 units of power left
# Bus 3 have still 20 minutes to drive
# Battery from bus 4 has 90 units of power left
# Bus 4 have still 50 minutes to drive
# Battery from bus 5 has 90 units of power left
# Bus 5 have still 30 minutes to drive
# Bus 6 waiting at the station
# Bus 7 waiting at the station
# Bus 8 waiting at the station
# Bus 6 starts route 2
# Bus 7 starts route 1
# Time is now 22
# Battery from bus 1 has 109 units of power left
# Bus 1 have still 89 minutes to drive
# Battery from bus 2 has 79 units of power left
# Bus 2 have still 39 minutes to drive
# Battery from bus 3 has 79 units of power left
# Bus 3 have still 19 minutes to drive
# Battery from bus 4 has 89 units of power left
# Bus 4 have still 49 minutes to drive
# Battery from bus 5 has 89 units of power left
# Bus 5 have still 29 minutes to drive
# Battery from bus 6 has 99 units of power left
# Bus 6 have still 59 minutes to drive
# Battery from bus 7 has 99 units of power left
# Bus 7 have still 39 minutes to drive
# Bus 8 waiting at the station
# Time is now 23
# Battery from bus 1 has 108 units of power left
# Bus 1 have still 88 minutes to drive
# Battery from bus 2 has 78 units of power left
# Bus 2 have still 38 minutes to drive
# Battery from bus 3 has 78 units of power left
# Bus 3 have still 18 minutes to drive
# Battery from bus 4 has 88 units of power left
# Bus 4 have still 48 minutes to drive
# Battery from bus 5 has 88 units of power left
# Bus 5 have still 28 minutes to drive
# Battery from bus 6 has 98 units of power left
# Bus 6 have still 58 minutes to drive
# Battery from bus 7 has 98 units of power left
# Bus 7 have still 38 minutes to drive
# Bus 8 waiting at the station
# Time is now 24
# Battery from bus 1 has 107 units of power left
# Bus 1 have still 87 minutes to drive
# Battery from bus 2 has 77 units of power left
# Bus 2 have still 37 minutes to drive
# Battery from bus 3 has 77 units of power left
# Bus 3 have still 17 minutes to drive
# Battery from bus 4 has 87 units of power left
# Bus 4 have still 47 minutes to drive
# Battery from bus 5 has 87 units of power left
# Bus 5 have still 27 minutes to drive
# Battery from bus 6 has 97 units of power left
# Bus 6 have still 57 minutes to drive
# Battery from bus 7 has 97 units of power left
# Bus 7 have still 37 minutes to drive
# Bus 8 waiting at the station
# Time is now 25
# Battery from bus 1 has 106 units of power left
# Bus 1 have still 86 minutes to drive
# Battery from bus 2 has 76 units of power left
# Bus 2 have still 36 minutes to drive
# Battery from bus 3 has 76 units of power left
# Bus 3 have still 16 minutes to drive
# Battery from bus 4 has 86 units of power left
# Bus 4 have still 46 minutes to drive
# Battery from bus 5 has 86 units of power left
# Bus 5 have still 26 minutes to drive
# Battery from bus 6 has 96 units of power left
# Bus 6 have still 56 minutes to drive
# Battery from bus 7 has 96 units of power left
# Bus 7 have still 36 minutes to drive
# Bus 8 waiting at the station
# Time is now 26
# Battery from bus 1 has 105 units of power left
# Bus 1 have still 85 minutes to drive
# Battery from bus 2 has 75 units of power left
# Bus 2 have still 35 minutes to drive
# Battery from bus 3 has 75 units of power left
# Bus 3 have still 15 minutes to drive
# Battery from bus 4 has 85 units of power left
# Bus 4 have still 45 minutes to drive
# Battery from bus 5 has 85 units of power left
# Bus 5 have still 25 minutes to drive
# Battery from bus 6 has 95 units of power left
# Bus 6 have still 55 minutes to drive
# Battery from bus 7 has 95 units of power left
# Bus 7 have still 35 minutes to drive
# Bus 8 waiting at the station
# Time is now 27
# Battery from bus 1 has 104 units of power left
# Bus 1 have still 84 minutes to drive
# Battery from bus 2 has 74 units of power left
# Bus 2 have still 34 minutes to drive
# Battery from bus 3 has 74 units of power left
# Bus 3 have still 14 minutes to drive
# Battery from bus 4 has 84 units of power left
# Bus 4 have still 44 minutes to drive
# Battery from bus 5 has 84 units of power left
# Bus 5 have still 24 minutes to drive
# Battery from bus 6 has 94 units of power left
# Bus 6 have still 54 minutes to drive
# Battery from bus 7 has 94 units of power left
# Bus 7 have still 34 minutes to drive
# Bus 8 waiting at the station
# Time is now 28
# Battery from bus 1 has 103 units of power left
# Bus 1 have still 83 minutes to drive
# Battery from bus 2 has 73 units of power left
# Bus 2 have still 33 minutes to drive
# Battery from bus 3 has 73 units of power left
# Bus 3 have still 13 minutes to drive
# Battery from bus 4 has 83 units of power left
# Bus 4 have still 43 minutes to drive
# Battery from bus 5 has 83 units of power left
# Bus 5 have still 23 minutes to drive
# Battery from bus 6 has 93 units of power left
# Bus 6 have still 53 minutes to drive
# Battery from bus 7 has 93 units of power left
# Bus 7 have still 33 minutes to drive
# Bus 8 waiting at the station
# Time is now 29
# Battery from bus 1 has 102 units of power left
# Bus 1 have still 82 minutes to drive
# Battery from bus 2 has 72 units of power left
# Bus 2 have still 32 minutes to drive
# Battery from bus 3 has 72 units of power left
# Bus 3 have still 12 minutes to drive
# Battery from bus 4 has 82 units of power left
# Bus 4 have still 42 minutes to drive
# Battery from bus 5 has 82 units of power left
# Bus 5 have still 22 minutes to drive
# Battery from bus 6 has 92 units of power left
# Bus 6 have still 52 minutes to drive
# Battery from bus 7 has 92 units of power left
# Bus 7 have still 32 minutes to drive
# Bus 8 waiting at the station
# Time is now 30
# Battery from bus 1 has 101 units of power left
# Bus 1 have still 81 minutes to drive
# Battery from bus 2 has 71 units of power left
# Bus 2 have still 31 minutes to drive
# Battery from bus 3 has 71 units of power left
# Bus 3 have still 11 minutes to drive
# Battery from bus 4 has 81 units of power left
# Bus 4 have still 41 minutes to drive
# Battery from bus 5 has 81 units of power left
# Bus 5 have still 21 minutes to drive
# Battery from bus 6 has 91 units of power left
# Bus 6 have still 51 minutes to drive
# Battery from bus 7 has 91 units of power left
# Bus 7 have still 31 minutes to drive
# Bus 8 waiting at the station
# Time is now 31
# Battery from bus 1 has 100 units of power left
# Bus 1 have still 80 minutes to drive
# Battery from bus 2 has 70 units of power left
# Bus 2 have still 30 minutes to drive
# Battery from bus 3 has 70 units of power left
# Bus 3 have still 10 minutes to drive
# Battery from bus 4 has 80 units of power left
# Bus 4 have still 40 minutes to drive
# Battery from bus 5 has 80 units of power left
# Bus 5 have still 20 minutes to drive
# Battery from bus 6 has 90 units of power left
# Bus 6 have still 50 minutes to drive
# Battery from bus 7 has 90 units of power left
# Bus 7 have still 30 minutes to drive
# Bus 8 waiting at the station
# Bus 8 starts route 2
# Not enough buses at the station or with enough battery...
# Time is now 32
# Battery from bus 1 has 99 units of power left
# Bus 1 have still 79 minutes to drive
# Battery from bus 2 has 69 units of power left
# Bus 2 have still 29 minutes to drive
# Battery from bus 3 has 69 units of power left
# Bus 3 have still 9 minutes to drive
# Battery from bus 4 has 79 units of power left
# Bus 4 have still 39 minutes to drive
# Battery from bus 5 has 79 units of power left
# Bus 5 have still 19 minutes to drive
# Battery from bus 6 has 89 units of power left
# Bus 6 have still 49 minutes to drive
# Battery from bus 7 has 89 units of power left
# Bus 7 have still 29 minutes to drive
# Battery from bus 8 has 99 units of power left
# Bus 8 have still 59 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 33
# Battery from bus 1 has 98 units of power left
# Bus 1 have still 78 minutes to drive
# Battery from bus 2 has 68 units of power left
# Bus 2 have still 28 minutes to drive
# Battery from bus 3 has 68 units of power left
# Bus 3 have still 8 minutes to drive
# Battery from bus 4 has 78 units of power left
# Bus 4 have still 38 minutes to drive
# Battery from bus 5 has 78 units of power left
# Bus 5 have still 18 minutes to drive
# Battery from bus 6 has 88 units of power left
# Bus 6 have still 48 minutes to drive
# Battery from bus 7 has 88 units of power left
# Bus 7 have still 28 minutes to drive
# Battery from bus 8 has 98 units of power left
# Bus 8 have still 58 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 34
# Battery from bus 1 has 97 units of power left
# Bus 1 have still 77 minutes to drive
# Battery from bus 2 has 67 units of power left
# Bus 2 have still 27 minutes to drive
# Battery from bus 3 has 67 units of power left
# Bus 3 have still 7 minutes to drive
# Battery from bus 4 has 77 units of power left
# Bus 4 have still 37 minutes to drive
# Battery from bus 5 has 77 units of power left
# Bus 5 have still 17 minutes to drive
# Battery from bus 6 has 87 units of power left
# Bus 6 have still 47 minutes to drive
# Battery from bus 7 has 87 units of power left
# Bus 7 have still 27 minutes to drive
# Battery from bus 8 has 97 units of power left
# Bus 8 have still 57 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 35
# Battery from bus 1 has 96 units of power left
# Bus 1 have still 76 minutes to drive
# Battery from bus 2 has 66 units of power left
# Bus 2 have still 26 minutes to drive
# Battery from bus 3 has 66 units of power left
# Bus 3 have still 6 minutes to drive
# Battery from bus 4 has 76 units of power left
# Bus 4 have still 36 minutes to drive
# Battery from bus 5 has 76 units of power left
# Bus 5 have still 16 minutes to drive
# Battery from bus 6 has 86 units of power left
# Bus 6 have still 46 minutes to drive
# Battery from bus 7 has 86 units of power left
# Bus 7 have still 26 minutes to drive
# Battery from bus 8 has 96 units of power left
# Bus 8 have still 56 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 36
# Battery from bus 1 has 95 units of power left
# Bus 1 have still 75 minutes to drive
# Battery from bus 2 has 65 units of power left
# Bus 2 have still 25 minutes to drive
# Battery from bus 3 has 65 units of power left
# Bus 3 have still 5 minutes to drive
# Battery from bus 4 has 75 units of power left
# Bus 4 have still 35 minutes to drive
# Battery from bus 5 has 75 units of power left
# Bus 5 have still 15 minutes to drive
# Battery from bus 6 has 85 units of power left
# Bus 6 have still 45 minutes to drive
# Battery from bus 7 has 85 units of power left
# Bus 7 have still 25 minutes to drive
# Battery from bus 8 has 95 units of power left
# Bus 8 have still 55 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 37
# Battery from bus 1 has 94 units of power left
# Bus 1 have still 74 minutes to drive
# Battery from bus 2 has 64 units of power left
# Bus 2 have still 24 minutes to drive
# Battery from bus 3 has 64 units of power left
# Bus 3 have still 4 minutes to drive
# Battery from bus 4 has 74 units of power left
# Bus 4 have still 34 minutes to drive
# Battery from bus 5 has 74 units of power left
# Bus 5 have still 14 minutes to drive
# Battery from bus 6 has 84 units of power left
# Bus 6 have still 44 minutes to drive
# Battery from bus 7 has 84 units of power left
# Bus 7 have still 24 minutes to drive
# Battery from bus 8 has 94 units of power left
# Bus 8 have still 54 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 38
# Battery from bus 1 has 93 units of power left
# Bus 1 have still 73 minutes to drive
# Battery from bus 2 has 63 units of power left
# Bus 2 have still 23 minutes to drive
# Battery from bus 3 has 63 units of power left
# Bus 3 have still 3 minutes to drive
# Battery from bus 4 has 73 units of power left
# Bus 4 have still 33 minutes to drive
# Battery from bus 5 has 73 units of power left
# Bus 5 have still 13 minutes to drive
# Battery from bus 6 has 83 units of power left
# Bus 6 have still 43 minutes to drive
# Battery from bus 7 has 83 units of power left
# Bus 7 have still 23 minutes to drive
# Battery from bus 8 has 93 units of power left
# Bus 8 have still 53 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 39
# Battery from bus 1 has 92 units of power left
# Bus 1 have still 72 minutes to drive
# Battery from bus 2 has 62 units of power left
# Bus 2 have still 22 minutes to drive
# Battery from bus 3 has 62 units of power left
# Bus 3 have still 2 minutes to drive
# Battery from bus 4 has 72 units of power left
# Bus 4 have still 32 minutes to drive
# Battery from bus 5 has 72 units of power left
# Bus 5 have still 12 minutes to drive
# Battery from bus 6 has 82 units of power left
# Bus 6 have still 42 minutes to drive
# Battery from bus 7 has 82 units of power left
# Bus 7 have still 22 minutes to drive
# Battery from bus 8 has 92 units of power left
# Bus 8 have still 52 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 40
# Battery from bus 1 has 91 units of power left
# Bus 1 have still 71 minutes to drive
# Battery from bus 2 has 61 units of power left
# Bus 2 have still 21 minutes to drive
# Battery from bus 3 has 61 units of power left
# Bus 3 have still 1 minutes to drive
# Battery from bus 4 has 71 units of power left
# Bus 4 have still 31 minutes to drive
# Battery from bus 5 has 71 units of power left
# Bus 5 have still 11 minutes to drive
# Battery from bus 6 has 81 units of power left
# Bus 6 have still 41 minutes to drive
# Battery from bus 7 has 81 units of power left
# Bus 7 have still 21 minutes to drive
# Battery from bus 8 has 91 units of power left
# Bus 8 have still 51 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 41
# Battery from bus 1 has 90 units of power left
# Bus 1 have still 70 minutes to drive
# Battery from bus 2 has 60 units of power left
# Bus 2 have still 20 minutes to drive
# Battery from bus 3 has 60 units of power left
# Bus 3 have still 0 minutes to drive
# Bus 3 is done, it is now at the station
# Battery from bus 4 has 70 units of power left
# Bus 4 have still 30 minutes to drive
# Battery from bus 5 has 70 units of power left
# Bus 5 have still 10 minutes to drive
# Battery from bus 6 has 80 units of power left
# Bus 6 have still 40 minutes to drive
# Battery from bus 7 has 80 units of power left
# Bus 7 have still 20 minutes to drive
# Battery from bus 8 has 90 units of power left
# Bus 8 have still 50 minutes to drive
# Bus 3 starts route 2
# Not enough buses at the station or with enough battery...
# Time is now 42
# Battery from bus 1 has 89 units of power left
# Bus 1 have still 69 minutes to drive
# Battery from bus 2 has 59 units of power left
# Bus 2 have still 19 minutes to drive
# Battery from bus 3 has 59 units of power left
# Bus 3 have still 59 minutes to drive
# Battery from bus 4 has 69 units of power left
# Bus 4 have still 29 minutes to drive
# Battery from bus 5 has 69 units of power left
# Bus 5 have still 9 minutes to drive
# Battery from bus 6 has 79 units of power left
# Bus 6 have still 39 minutes to drive
# Battery from bus 7 has 79 units of power left
# Bus 7 have still 19 minutes to drive
# Battery from bus 8 has 89 units of power left
# Bus 8 have still 49 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 43
# Battery from bus 1 has 88 units of power left
# Bus 1 have still 68 minutes to drive
# Battery from bus 2 has 58 units of power left
# Bus 2 have still 18 minutes to drive
# Battery from bus 3 has 58 units of power left
# Bus 3 have still 58 minutes to drive
# Battery from bus 4 has 68 units of power left
# Bus 4 have still 28 minutes to drive
# Battery from bus 5 has 68 units of power left
# Bus 5 have still 8 minutes to drive
# Battery from bus 6 has 78 units of power left
# Bus 6 have still 38 minutes to drive
# Battery from bus 7 has 78 units of power left
# Bus 7 have still 18 minutes to drive
# Battery from bus 8 has 88 units of power left
# Bus 8 have still 48 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 44
# Battery from bus 1 has 87 units of power left
# Bus 1 have still 67 minutes to drive
# Battery from bus 2 has 57 units of power left
# Bus 2 have still 17 minutes to drive
# Battery from bus 3 has 57 units of power left
# Bus 3 have still 57 minutes to drive
# Battery from bus 4 has 67 units of power left
# Bus 4 have still 27 minutes to drive
# Battery from bus 5 has 67 units of power left
# Bus 5 have still 7 minutes to drive
# Battery from bus 6 has 77 units of power left
# Bus 6 have still 37 minutes to drive
# Battery from bus 7 has 77 units of power left
# Bus 7 have still 17 minutes to drive
# Battery from bus 8 has 87 units of power left
# Bus 8 have still 47 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 45
# Battery from bus 1 has 86 units of power left
# Bus 1 have still 66 minutes to drive
# Battery from bus 2 has 56 units of power left
# Bus 2 have still 16 minutes to drive
# Battery from bus 3 has 56 units of power left
# Bus 3 have still 56 minutes to drive
# Battery from bus 4 has 66 units of power left
# Bus 4 have still 26 minutes to drive
# Battery from bus 5 has 66 units of power left
# Bus 5 have still 6 minutes to drive
# Battery from bus 6 has 76 units of power left
# Bus 6 have still 36 minutes to drive
# Battery from bus 7 has 76 units of power left
# Bus 7 have still 16 minutes to drive
# Battery from bus 8 has 86 units of power left
# Bus 8 have still 46 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 46
# Battery from bus 1 has 85 units of power left
# Bus 1 have still 65 minutes to drive
# Battery from bus 2 has 55 units of power left
# Bus 2 have still 15 minutes to drive
# Battery from bus 3 has 55 units of power left
# Bus 3 have still 55 minutes to drive
# Battery from bus 4 has 65 units of power left
# Bus 4 have still 25 minutes to drive
# Battery from bus 5 has 65 units of power left
# Bus 5 have still 5 minutes to drive
# Battery from bus 6 has 75 units of power left
# Bus 6 have still 35 minutes to drive
# Battery from bus 7 has 75 units of power left
# Bus 7 have still 15 minutes to drive
# Battery from bus 8 has 85 units of power left
# Bus 8 have still 45 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 47
# Battery from bus 1 has 84 units of power left
# Bus 1 have still 64 minutes to drive
# Battery from bus 2 has 54 units of power left
# Bus 2 have still 14 minutes to drive
# Battery from bus 3 has 54 units of power left
# Bus 3 have still 54 minutes to drive
# Battery from bus 4 has 64 units of power left
# Bus 4 have still 24 minutes to drive
# Battery from bus 5 has 64 units of power left
# Bus 5 have still 4 minutes to drive
# Battery from bus 6 has 74 units of power left
# Bus 6 have still 34 minutes to drive
# Battery from bus 7 has 74 units of power left
# Bus 7 have still 14 minutes to drive
# Battery from bus 8 has 84 units of power left
# Bus 8 have still 44 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 48
# Battery from bus 1 has 83 units of power left
# Bus 1 have still 63 minutes to drive
# Battery from bus 2 has 53 units of power left
# Bus 2 have still 13 minutes to drive
# Battery from bus 3 has 53 units of power left
# Bus 3 have still 53 minutes to drive
# Battery from bus 4 has 63 units of power left
# Bus 4 have still 23 minutes to drive
# Battery from bus 5 has 63 units of power left
# Bus 5 have still 3 minutes to drive
# Battery from bus 6 has 73 units of power left
# Bus 6 have still 33 minutes to drive
# Battery from bus 7 has 73 units of power left
# Bus 7 have still 13 minutes to drive
# Battery from bus 8 has 83 units of power left
# Bus 8 have still 43 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 49
# Battery from bus 1 has 82 units of power left
# Bus 1 have still 62 minutes to drive
# Battery from bus 2 has 52 units of power left
# Bus 2 have still 12 minutes to drive
# Battery from bus 3 has 52 units of power left
# Bus 3 have still 52 minutes to drive
# Battery from bus 4 has 62 units of power left
# Bus 4 have still 22 minutes to drive
# Battery from bus 5 has 62 units of power left
# Bus 5 have still 2 minutes to drive
# Battery from bus 6 has 72 units of power left
# Bus 6 have still 32 minutes to drive
# Battery from bus 7 has 72 units of power left
# Bus 7 have still 12 minutes to drive
# Battery from bus 8 has 82 units of power left
# Bus 8 have still 42 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 50
# Battery from bus 1 has 81 units of power left
# Bus 1 have still 61 minutes to drive
# Battery from bus 2 has 51 units of power left
# Bus 2 have still 11 minutes to drive
# Battery from bus 3 has 51 units of power left
# Bus 3 have still 51 minutes to drive
# Battery from bus 4 has 61 units of power left
# Bus 4 have still 21 minutes to drive
# Battery from bus 5 has 61 units of power left
# Bus 5 have still 1 minutes to drive
# Battery from bus 6 has 71 units of power left
# Bus 6 have still 31 minutes to drive
# Battery from bus 7 has 71 units of power left
# Bus 7 have still 11 minutes to drive
# Battery from bus 8 has 81 units of power left
# Bus 8 have still 41 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 51
# Battery from bus 1 has 80 units of power left
# Bus 1 have still 60 minutes to drive
# Battery from bus 2 has 50 units of power left
# Bus 2 have still 10 minutes to drive
# Battery from bus 3 has 50 units of power left
# Bus 3 have still 50 minutes to drive
# Battery from bus 4 has 60 units of power left
# Bus 4 have still 20 minutes to drive
# Battery from bus 5 has 60 units of power left
# Bus 5 have still 0 minutes to drive
# Bus 5 is done, it is now at the station
# Battery from bus 6 has 70 units of power left
# Bus 6 have still 30 minutes to drive
# Battery from bus 7 has 70 units of power left
# Bus 7 have still 10 minutes to drive
# Battery from bus 8 has 80 units of power left
# Bus 8 have still 40 minutes to drive
# Bus 5 starts route 2
# Not enough buses at the station or with enough battery...
# Time is now 52
# Battery from bus 1 has 79 units of power left
# Bus 1 have still 59 minutes to drive
# Battery from bus 2 has 49 units of power left
# Bus 2 have still 9 minutes to drive
# Battery from bus 3 has 49 units of power left
# Bus 3 have still 49 minutes to drive
# Battery from bus 4 has 59 units of power left
# Bus 4 have still 19 minutes to drive
# Battery from bus 5 has 59 units of power left
# Bus 5 have still 59 minutes to drive
# Battery from bus 6 has 69 units of power left
# Bus 6 have still 29 minutes to drive
# Battery from bus 7 has 69 units of power left
# Bus 7 have still 9 minutes to drive
# Battery from bus 8 has 79 units of power left
# Bus 8 have still 39 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 53
# Battery from bus 1 has 78 units of power left
# Bus 1 have still 58 minutes to drive
# Battery from bus 2 has 48 units of power left
# Bus 2 have still 8 minutes to drive
# Battery from bus 3 has 48 units of power left
# Bus 3 have still 48 minutes to drive
# Battery from bus 4 has 58 units of power left
# Bus 4 have still 18 minutes to drive
# Battery from bus 5 has 58 units of power left
# Bus 5 have still 58 minutes to drive
# Battery from bus 6 has 68 units of power left
# Bus 6 have still 28 minutes to drive
# Battery from bus 7 has 68 units of power left
# Bus 7 have still 8 minutes to drive
# Battery from bus 8 has 78 units of power left
# Bus 8 have still 38 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 54
# Battery from bus 1 has 77 units of power left
# Bus 1 have still 57 minutes to drive
# Battery from bus 2 has 47 units of power left
# Bus 2 have still 7 minutes to drive
# Battery from bus 3 has 47 units of power left
# Bus 3 have still 47 minutes to drive
# Battery from bus 4 has 57 units of power left
# Bus 4 have still 17 minutes to drive
# Battery from bus 5 has 57 units of power left
# Bus 5 have still 57 minutes to drive
# Battery from bus 6 has 67 units of power left
# Bus 6 have still 27 minutes to drive
# Battery from bus 7 has 67 units of power left
# Bus 7 have still 7 minutes to drive
# Battery from bus 8 has 77 units of power left
# Bus 8 have still 37 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 55
# Battery from bus 1 has 76 units of power left
# Bus 1 have still 56 minutes to drive
# Battery from bus 2 has 46 units of power left
# Bus 2 have still 6 minutes to drive
# Battery from bus 3 has 46 units of power left
# Bus 3 have still 46 minutes to drive
# Battery from bus 4 has 56 units of power left
# Bus 4 have still 16 minutes to drive
# Battery from bus 5 has 56 units of power left
# Bus 5 have still 56 minutes to drive
# Battery from bus 6 has 66 units of power left
# Bus 6 have still 26 minutes to drive
# Battery from bus 7 has 66 units of power left
# Bus 7 have still 6 minutes to drive
# Battery from bus 8 has 76 units of power left
# Bus 8 have still 36 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 56
# Battery from bus 1 has 75 units of power left
# Bus 1 have still 55 minutes to drive
# Battery from bus 2 has 45 units of power left
# Bus 2 have still 5 minutes to drive
# Battery from bus 3 has 45 units of power left
# Bus 3 have still 45 minutes to drive
# Battery from bus 4 has 55 units of power left
# Bus 4 have still 15 minutes to drive
# Battery from bus 5 has 55 units of power left
# Bus 5 have still 55 minutes to drive
# Battery from bus 6 has 65 units of power left
# Bus 6 have still 25 minutes to drive
# Battery from bus 7 has 65 units of power left
# Bus 7 have still 5 minutes to drive
# Battery from bus 8 has 75 units of power left
# Bus 8 have still 35 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 57
# Battery from bus 1 has 74 units of power left
# Bus 1 have still 54 minutes to drive
# Battery from bus 2 has 44 units of power left
# Bus 2 have still 4 minutes to drive
# Battery from bus 3 has 44 units of power left
# Bus 3 have still 44 minutes to drive
# Battery from bus 4 has 54 units of power left
# Bus 4 have still 14 minutes to drive
# Battery from bus 5 has 54 units of power left
# Bus 5 have still 54 minutes to drive
# Battery from bus 6 has 64 units of power left
# Bus 6 have still 24 minutes to drive
# Battery from bus 7 has 64 units of power left
# Bus 7 have still 4 minutes to drive
# Battery from bus 8 has 74 units of power left
# Bus 8 have still 34 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 58
# Battery from bus 1 has 73 units of power left
# Bus 1 have still 53 minutes to drive
# Battery from bus 2 has 43 units of power left
# Bus 2 have still 3 minutes to drive
# Battery from bus 3 has 43 units of power left
# Bus 3 have still 43 minutes to drive
# Battery from bus 4 has 53 units of power left
# Bus 4 have still 13 minutes to drive
# Battery from bus 5 has 53 units of power left
# Bus 5 have still 53 minutes to drive
# Battery from bus 6 has 63 units of power left
# Bus 6 have still 23 minutes to drive
# Battery from bus 7 has 63 units of power left
# Bus 7 have still 3 minutes to drive
# Battery from bus 8 has 73 units of power left
# Bus 8 have still 33 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 59
# Battery from bus 1 has 72 units of power left
# Bus 1 have still 52 minutes to drive
# Battery from bus 2 has 42 units of power left
# Bus 2 have still 2 minutes to drive
# Battery from bus 3 has 42 units of power left
# Bus 3 have still 42 minutes to drive
# Battery from bus 4 has 52 units of power left
# Bus 4 have still 12 minutes to drive
# Battery from bus 5 has 52 units of power left
# Bus 5 have still 52 minutes to drive
# Battery from bus 6 has 62 units of power left
# Bus 6 have still 22 minutes to drive
# Battery from bus 7 has 62 units of power left
# Bus 7 have still 2 minutes to drive
# Battery from bus 8 has 72 units of power left
# Bus 8 have still 32 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 60
# Battery from bus 1 has 71 units of power left
# Bus 1 have still 51 minutes to drive
# Battery from bus 2 has 41 units of power left
# Bus 2 have still 1 minutes to drive
# Battery from bus 3 has 41 units of power left
# Bus 3 have still 41 minutes to drive
# Battery from bus 4 has 51 units of power left
# Bus 4 have still 11 minutes to drive
# Battery from bus 5 has 51 units of power left
# Bus 5 have still 51 minutes to drive
# Battery from bus 6 has 61 units of power left
# Bus 6 have still 21 minutes to drive
# Battery from bus 7 has 61 units of power left
# Bus 7 have still 1 minutes to drive
# Battery from bus 8 has 71 units of power left
# Bus 8 have still 31 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# Time is now 61
# Battery from bus 1 has 70 units of power left
# Bus 1 have still 50 minutes to drive
# Battery from bus 2 has 40 units of power left
# Bus 2 have still 0 minutes to drive
# Bus 2 is done, it is now at the station
# Battery from bus 3 has 40 units of power left
# Bus 3 have still 40 minutes to drive
# Battery from bus 4 has 50 units of power left
# Bus 4 have still 10 minutes to drive
# Battery from bus 5 has 50 units of power left
# Bus 5 have still 50 minutes to drive
# Battery from bus 6 has 60 units of power left
# Bus 6 have still 20 minutes to drive
# Battery from bus 7 has 60 units of power left
# Bus 7 have still 0 minutes to drive
# Bus 7 is done, it is now at the station
# Battery from bus 8 has 70 units of power left
# Bus 8 have still 30 minutes to drive
# Bus 7 starts route 2
# Bus 2 starts route 1
# Time is now 62
# Battery from bus 1 has 69 units of power left
# Bus 1 have still 49 minutes to drive
# Battery from bus 2 has 39 units of power left
# Bus 2 have still 39 minutes to drive
# Battery from bus 3 has 39 units of power left
# Bus 3 have still 39 minutes to drive
# Battery from bus 4 has 49 units of power left
# Bus 4 have still 9 minutes to drive
# Battery from bus 5 has 49 units of power left
# Bus 5 have still 49 minutes to drive
# Battery from bus 6 has 59 units of power left
# Bus 6 have still 19 minutes to drive
# Battery from bus 7 has 59 units of power left
# Bus 7 have still 59 minutes to drive
# Battery from bus 8 has 69 units of power left
# Bus 8 have still 29 minutes to drive
# Not enough buses at the station or with enough battery...
# Time is now 63
# Battery from bus 1 has 68 units of power left
# Bus 1 have still 48 minutes to drive
# Battery from bus 2 has 38 units of power left
# Bus 2 have still 38 minutes to drive
# Battery from bus 3 has 38 units of power left
# Bus 3 have still 38 minutes to drive
# Battery from bus 4 has 48 units of power left
# Bus 4 have still 8 minutes to drive
# Battery from bus 5 has 48 units of power left
# Bus 5 have still 48 minutes to drive
# Battery from bus 6 has 58 units of power left
# Bus 6 have still 18 minutes to drive
# Battery from bus 7 has 58 units of power left
# Bus 7 have still 58 minutes to drive
# Battery from bus 8 has 68 units of power left
# Bus 8 have still 28 minutes to drive
# Not enough buses at the station or with enough battery...
# Time is now 64
# Battery from bus 1 has 67 units of power left
# Bus 1 have still 47 minutes to drive
# Battery from bus 2 has 37 units of power left
# Bus 2 have still 37 minutes to drive
# Battery from bus 3 has 37 units of power left
# Bus 3 have still 37 minutes to drive
# Battery from bus 4 has 47 units of power left
# Bus 4 have still 7 minutes to drive
# Battery from bus 5 has 47 units of power left
# Bus 5 have still 47 minutes to drive
# Battery from bus 6 has 57 units of power left
# Bus 6 have still 17 minutes to drive
# Battery from bus 7 has 57 units of power left
# Bus 7 have still 57 minutes to drive
# Battery from bus 8 has 67 units of power left
# Bus 8 have still 27 minutes to drive
# Not enough buses at the station or with enough battery...
# Time is now 65
# Battery from bus 1 has 66 units of power left
# Bus 1 have still 46 minutes to drive
# Battery from bus 2 has 36 units of power left
# Bus 2 have still 36 minutes to drive
# Battery from bus 3 has 36 units of power left
# Bus 3 have still 36 minutes to drive
# Battery from bus 4 has 46 units of power left
# Bus 4 have still 6 minutes to drive
# Battery from bus 5 has 46 units of power left
# Bus 5 have still 46 minutes to drive
# Battery from bus 6 has 56 units of power left
# Bus 6 have still 16 minutes to drive
# Battery from bus 7 has 56 units of power left
# Bus 7 have still 56 minutes to drive
# Battery from bus 8 has 66 units of power left
# Bus 8 have still 26 minutes to drive
# Not enough buses at the station or with enough battery...
# Time is now 66
# Battery from bus 1 has 65 units of power left
# Bus 1 have still 45 minutes to drive
# Battery from bus 2 has 35 units of power left
# Bus 2 have still 35 minutes to drive
# Battery from bus 3 has 35 units of power left
# Bus 3 have still 35 minutes to drive
# Battery from bus 4 has 45 units of power left
# Bus 4 have still 5 minutes to drive
# Battery from bus 5 has 45 units of power left
# Bus 5 have still 45 minutes to drive
# Battery from bus 6 has 55 units of power left
# Bus 6 have still 15 minutes to drive
# Battery from bus 7 has 55 units of power left
# Bus 7 have still 55 minutes to drive
# Battery from bus 8 has 65 units of power left
# Bus 8 have still 25 minutes to drive
# Not enough buses at the station or with enough battery...
# Time is now 67
# Battery from bus 1 has 64 units of power left
# Bus 1 have still 44 minutes to drive
# Battery from bus 2 has 34 units of power left
# Bus 2 have still 34 minutes to drive
# Battery from bus 3 has 34 units of power left
# Bus 3 have still 34 minutes to drive
# Battery from bus 4 has 44 units of power left
# Bus 4 have still 4 minutes to drive
# Battery from bus 5 has 44 units of power left
# Bus 5 have still 44 minutes to drive
# Battery from bus 6 has 54 units of power left
# Bus 6 have still 14 minutes to drive
# Battery from bus 7 has 54 units of power left
# Bus 7 have still 54 minutes to drive
# Battery from bus 8 has 64 units of power left
# Bus 8 have still 24 minutes to drive
# Not enough buses at the station or with enough battery...
# Time is now 68
# Battery from bus 1 has 63 units of power left
# Bus 1 have still 43 minutes to drive
# Battery from bus 2 has 33 units of power left
# Bus 2 have still 33 minutes to drive
# Battery from bus 3 has 33 units of power left
# Bus 3 have still 33 minutes to drive
# Battery from bus 4 has 43 units of power left
# Bus 4 have still 3 minutes to drive
# Battery from bus 5 has 43 units of power left
# Bus 5 have still 43 minutes to drive
# Battery from bus 6 has 53 units of power left
# Bus 6 have still 13 minutes to drive
# Battery from bus 7 has 53 units of power left
# Bus 7 have still 53 minutes to drive
# Battery from bus 8 has 63 units of power left
# Bus 8 have still 23 minutes to drive
# Not enough buses at the station or with enough battery...
# Time is now 69
# Battery from bus 1 has 62 units of power left
# Bus 1 have still 42 minutes to drive
# Battery from bus 2 has 32 units of power left
# Bus 2 have still 32 minutes to drive
# Battery from bus 3 has 32 units of power left
# Bus 3 have still 32 minutes to drive
# Battery from bus 4 has 42 units of power left
# Bus 4 have still 2 minutes to drive
# Battery from bus 5 has 42 units of power left
# Bus 5 have still 42 minutes to drive
# Battery from bus 6 has 52 units of power left
# Bus 6 have still 12 minutes to drive
# Battery from bus 7 has 52 units of power left
# Bus 7 have still 52 minutes to drive
# Battery from bus 8 has 62 units of power left
# Bus 8 have still 22 minutes to drive
# Not enough buses at the station or with enough battery...
# Time is now 70
# Battery from bus 1 has 61 units of power left
# Bus 1 have still 41 minutes to drive
# Battery from bus 2 has 31 units of power left
# Bus 2 have still 31 minutes to drive
# Battery from bus 3 has 31 units of power left
# Bus 3 have still 31 minutes to drive
# Battery from bus 4 has 41 units of power left
# Bus 4 have still 1 minutes to drive
# Battery from bus 5 has 41 units of power left
# Bus 5 have still 41 minutes to drive
# Battery from bus 6 has 51 units of power left
# Bus 6 have still 11 minutes to drive
# Battery from bus 7 has 51 units of power left
# Bus 7 have still 51 minutes to drive
# Battery from bus 8 has 61 units of power left
# Bus 8 have still 21 minutes to drive
# Not enough buses at the station or with enough battery...
# Time is now 71
# Battery from bus 1 has 60 units of power left
# Bus 1 have still 40 minutes to drive
# Battery from bus 2 has 30 units of power left
# Bus 2 have still 30 minutes to drive
# Battery from bus 3 has 30 units of power left
# Bus 3 have still 30 minutes to drive
# Battery from bus 4 has 40 units of power left
# Bus 4 have still 0 minutes to drive
# Bus 4 is done, it is now at the station
# Battery from bus 5 has 40 units of power left
# Bus 5 have still 40 minutes to drive
# Battery from bus 6 has 50 units of power left
# Bus 6 have still 10 minutes to drive
# Battery from bus 7 has 50 units of power left
# Bus 7 have still 50 minutes to drive
# Battery from bus 8 has 60 units of power left
# Bus 8 have still 20 minutes to drive
# Bus 4 starts route 1
# Time is now 72
# Battery from bus 1 has 59 units of power left
# Bus 1 have still 39 minutes to drive
# Battery from bus 2 has 29 units of power left
# Bus 2 have still 29 minutes to drive
# Battery from bus 3 has 29 units of power left
# Bus 3 have still 29 minutes to drive
# Battery from bus 4 has 39 units of power left
# Bus 4 have still 39 minutes to drive
# Battery from bus 5 has 39 units of power left
# Bus 5 have still 39 minutes to drive
# Battery from bus 6 has 49 units of power left
# Bus 6 have still 9 minutes to drive
# Battery from bus 7 has 49 units of power left
# Bus 7 have still 49 minutes to drive
# Battery from bus 8 has 59 units of power left
# Bus 8 have still 19 minutes to drive
# Not enough buses at the station or with enough battery...
# Not enough buses at the station or with enough battery...
# ...
# Battery from bus 4 has 46 units of power left
# Bus 4 have still 34 minutes to drive
# Battery from bus 5 has 19 units of power left
# Bus 5 have still 4 minutes to drive
# Bus 6 waiting at the station
# Battery from bus 7 has 29 units of power left
# Bus 7 have still 14 minutes to drive
# Bus 8 waiting at the station
# Bus 6 fastly charging => 47/100
# Bus 8 fastly charging => 30/100
# Bus 3 fastly charging => 27/100
# Time is now 276
# Battery from bus 1 has 31 units of power left
# Bus 1 have still 30 minutes to drive
# Battery from bus 2 has 35 units of power left
# Bus 2 have still 23 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 45 units of power left
# Bus 4 have still 33 minutes to drive
# Battery from bus 5 has 18 units of power left
# Bus 5 have still 3 minutes to drive
# Bus 6 waiting at the station
# Battery from bus 7 has 28 units of power left
# Bus 7 have still 13 minutes to drive
# Bus 8 waiting at the station
# Bus 6 fastly charging => 49/100
# Bus 8 fastly charging => 32/100
# Bus 3 fastly charging => 29/100
# Time is now 277
# Battery from bus 1 has 30 units of power left
# Bus 1 have still 29 minutes to drive
# Battery from bus 2 has 34 units of power left
# Bus 2 have still 22 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 44 units of power left
# Bus 4 have still 32 minutes to drive
# Battery from bus 5 has 17 units of power left
# Bus 5 have still 2 minutes to drive
# Bus 6 waiting at the station
# Battery from bus 7 has 27 units of power left
# Bus 7 have still 12 minutes to drive
# Bus 8 waiting at the station
# Bus 6 fastly charging => 50/100
# Bus 8 fastly charging => 33/100
# Bus 3 fastly charging => 30/100
# Time is now 278
# Battery from bus 1 has 29 units of power left
# Bus 1 have still 28 minutes to drive
# Battery from bus 2 has 33 units of power left
# Bus 2 have still 21 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 43 units of power left
# Bus 4 have still 31 minutes to drive
# Battery from bus 5 has 16 units of power left
# Bus 5 have still 1 minutes to drive
# Bus 6 waiting at the station
# Battery from bus 7 has 26 units of power left
# Bus 7 have still 11 minutes to drive
# Bus 8 waiting at the station
# Bus 6 fastly charging => 52/100
# Bus 8 fastly charging => 35/100
# Bus 3 fastly charging => 32/100
# Time is now 279
# Battery from bus 1 has 28 units of power left
# Bus 1 have still 27 minutes to drive
# Battery from bus 2 has 32 units of power left
# Bus 2 have still 20 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 42 units of power left
# Bus 4 have still 30 minutes to drive
# Battery from bus 5 has 15 units of power left
# Bus 5 have still 0 minutes to drive
# Bus 5 is done, it is now at the station
# Bus 6 waiting at the station
# Battery from bus 7 has 25 units of power left
# Bus 7 have still 10 minutes to drive
# Bus 8 waiting at the station
# Bus 6 starts route 1
# Bus 8 fastly charging => 37/100
# Bus 3 fastly charging => 34/100
# Bus 5 fastly charging => 17/100
# Time is now 280
# Battery from bus 1 has 27 units of power left
# Bus 1 have still 26 minutes to drive
# Battery from bus 2 has 31 units of power left
# Bus 2 have still 19 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 41 units of power left
# Bus 4 have still 29 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 51 units of power left
# Bus 6 have still 39 minutes to drive
# Battery from bus 7 has 24 units of power left
# Bus 7 have still 9 minutes to drive
# Bus 8 waiting at the station
# Bus 8 fastly charging => 39/100
# Bus 3 fastly charging => 36/100
# Bus 5 fastly charging => 19/100
# Time is now 281
# Battery from bus 1 has 26 units of power left
# Bus 1 have still 25 minutes to drive
# Battery from bus 2 has 30 units of power left
# Bus 2 have still 18 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 40 units of power left
# Bus 4 have still 28 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 50 units of power left
# Bus 6 have still 38 minutes to drive
# Battery from bus 7 has 23 units of power left
# Bus 7 have still 8 minutes to drive
# Bus 8 waiting at the station
# Bus 8 fastly charging => 40/100
# Bus 3 fastly charging => 37/100
# Bus 5 fastly charging => 20/100
# Time is now 282
# Battery from bus 1 has 25 units of power left
# Bus 1 have still 24 minutes to drive
# Battery from bus 2 has 29 units of power left
# Bus 2 have still 17 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 39 units of power left
# Bus 4 have still 27 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 49 units of power left
# Bus 6 have still 37 minutes to drive
# Battery from bus 7 has 22 units of power left
# Bus 7 have still 7 minutes to drive
# Bus 8 waiting at the station
# Bus 8 fastly charging => 42/100
# Bus 3 fastly charging => 39/100
# Bus 5 fastly charging => 22/100
# Time is now 283
# Battery from bus 1 has 24 units of power left
# Bus 1 have still 23 minutes to drive
# Battery from bus 2 has 28 units of power left
# Bus 2 have still 16 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 38 units of power left
# Bus 4 have still 26 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 48 units of power left
# Bus 6 have still 36 minutes to drive
# Battery from bus 7 has 21 units of power left
# Bus 7 have still 6 minutes to drive
# Bus 8 waiting at the station
# Bus 8 fastly charging => 44/100
# Bus 3 fastly charging => 41/100
# Bus 5 fastly charging => 24/100
# Time is now 284
# Battery from bus 1 has 23 units of power left
# Bus 1 have still 22 minutes to drive
# Battery from bus 2 has 27 units of power left
# Bus 2 have still 15 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 37 units of power left
# Bus 4 have still 25 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 47 units of power left
# Bus 6 have still 35 minutes to drive
# Battery from bus 7 has 20 units of power left
# Bus 7 have still 5 minutes to drive
# Bus 8 waiting at the station
# Bus 8 fastly charging => 45/100
# Bus 3 fastly charging => 42/100
# Bus 5 fastly charging => 25/100
# Time is now 285
# Battery from bus 1 has 22 units of power left
# Bus 1 have still 21 minutes to drive
# Battery from bus 2 has 26 units of power left
# Bus 2 have still 14 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 36 units of power left
# Bus 4 have still 24 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 46 units of power left
# Bus 6 have still 34 minutes to drive
# Battery from bus 7 has 19 units of power left
# Bus 7 have still 4 minutes to drive
# Bus 8 waiting at the station
# Bus 8 fastly charging => 47/100
# Bus 3 fastly charging => 44/100
# Bus 5 fastly charging => 27/100
# Time is now 286
# Battery from bus 1 has 21 units of power left
# Bus 1 have still 20 minutes to drive
# Battery from bus 2 has 25 units of power left
# Bus 2 have still 13 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 35 units of power left
# Bus 4 have still 23 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 45 units of power left
# Bus 6 have still 33 minutes to drive
# Battery from bus 7 has 18 units of power left
# Bus 7 have still 3 minutes to drive
# Bus 8 waiting at the station
# Bus 8 fastly charging => 49/100
# Bus 3 fastly charging => 46/100
# Bus 5 fastly charging => 29/100
# Time is now 287
# Battery from bus 1 has 20 units of power left
# Bus 1 have still 19 minutes to drive
# Battery from bus 2 has 24 units of power left
# Bus 2 have still 12 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 34 units of power left
# Bus 4 have still 22 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 44 units of power left
# Bus 6 have still 32 minutes to drive
# Battery from bus 7 has 17 units of power left
# Bus 7 have still 2 minutes to drive
# Bus 8 waiting at the station
# Bus 8 fastly charging => 50/100
# Bus 3 fastly charging => 47/100
# Bus 5 fastly charging => 30/100
# Time is now 288
# Battery from bus 1 has 19 units of power left
# Bus 1 have still 18 minutes to drive
# Battery from bus 2 has 23 units of power left
# Bus 2 have still 11 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 33 units of power left
# Bus 4 have still 21 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 43 units of power left
# Bus 6 have still 31 minutes to drive
# Battery from bus 7 has 16 units of power left
# Bus 7 have still 1 minutes to drive
# Bus 8 waiting at the station
# Bus 8 fastly charging => 52/100
# Bus 3 fastly charging => 49/100
# Bus 5 fastly charging => 32/100
# Time is now 289
# Battery from bus 1 has 18 units of power left
# Bus 1 have still 17 minutes to drive
# Battery from bus 2 has 22 units of power left
# Bus 2 have still 10 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 32 units of power left
# Bus 4 have still 20 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 42 units of power left
# Bus 6 have still 30 minutes to drive
# Battery from bus 7 has 15 units of power left
# Bus 7 have still 0 minutes to drive
# Bus 7 is done, it is now at the station
# Bus 8 waiting at the station
# Bus 8 starts route 1
# Bus 3 fastly charging => 51/100
# Bus 5 fastly charging => 34/100
# Bus 7 fastly charging => 17/100
# Time is now 290
# Battery from bus 1 has 17 units of power left
# Bus 1 have still 16 minutes to drive
# Battery from bus 2 has 21 units of power left
# Bus 2 have still 9 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 31 units of power left
# Bus 4 have still 19 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 41 units of power left
# Bus 6 have still 29 minutes to drive
# Bus 7 waiting at the station
# Battery from bus 8 has 51 units of power left
# Bus 8 have still 39 minutes to drive
# Bus 3 fastly charging => 53/100
# Bus 5 fastly charging => 36/100
# Bus 7 fastly charging => 19/100
# Time is now 291
# Battery from bus 1 has 16 units of power left
# Bus 1 have still 15 minutes to drive
# Battery from bus 2 has 20 units of power left
# Bus 2 have still 8 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 30 units of power left
# Bus 4 have still 18 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 40 units of power left
# Bus 6 have still 28 minutes to drive
# Bus 7 waiting at the station
# Battery from bus 8 has 50 units of power left
# Bus 8 have still 38 minutes to drive
# Bus 3 fastly charging => 54/100
# Bus 5 fastly charging => 37/100
# Bus 7 fastly charging => 20/100
# Time is now 292
# Battery from bus 1 has 15 units of power left
# Bus 1 have still 14 minutes to drive
# Battery from bus 2 has 19 units of power left
# Bus 2 have still 7 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 29 units of power left
# Bus 4 have still 17 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 39 units of power left
# Bus 6 have still 27 minutes to drive
# Bus 7 waiting at the station
# Battery from bus 8 has 49 units of power left
# Bus 8 have still 37 minutes to drive
# Bus 3 fastly charging => 56/100
# Bus 5 fastly charging => 39/100
# Bus 7 fastly charging => 22/100
# Time is now 293
# Battery from bus 1 has 14 units of power left
# Bus 1 have still 13 minutes to drive
# Battery from bus 2 has 18 units of power left
# Bus 2 have still 6 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 28 units of power left
# Bus 4 have still 16 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 38 units of power left
# Bus 6 have still 26 minutes to drive
# Bus 7 waiting at the station
# Battery from bus 8 has 48 units of power left
# Bus 8 have still 36 minutes to drive
# Bus 3 fastly charging => 58/100
# Bus 5 fastly charging => 41/100
# Bus 7 fastly charging => 24/100
# Time is now 294
# Battery from bus 1 has 13 units of power left
# Bus 1 have still 12 minutes to drive
# Battery from bus 2 has 17 units of power left
# Bus 2 have still 5 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 27 units of power left
# Bus 4 have still 15 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 37 units of power left
# Bus 6 have still 25 minutes to drive
# Bus 7 waiting at the station
# Battery from bus 8 has 47 units of power left
# Bus 8 have still 35 minutes to drive
# Bus 3 fastly charging => 59/100
# Bus 5 fastly charging => 42/100
# Bus 7 fastly charging => 25/100
# Time is now 295
# Battery from bus 1 has 12 units of power left
# Bus 1 have still 11 minutes to drive
# Battery from bus 2 has 16 units of power left
# Bus 2 have still 4 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 26 units of power left
# Bus 4 have still 14 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 36 units of power left
# Bus 6 have still 24 minutes to drive
# Bus 7 waiting at the station
# Battery from bus 8 has 46 units of power left
# Bus 8 have still 34 minutes to drive
# Bus 3 fastly charging => 61/100
# Bus 5 fastly charging => 44/100
# Bus 7 fastly charging => 27/100
# Time is now 296
# Battery from bus 1 has 11 units of power left
# Bus 1 have still 10 minutes to drive
# Battery from bus 2 has 15 units of power left
# Bus 2 have still 3 minutes to drive
# Bus 3 waiting at the station
# Battery from bus 4 has 25 units of power left
# Bus 4 have still 13 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 35 units of power left
# Bus 6 have still 23 minutes to drive
# Bus 7 waiting at the station
# Battery from bus 8 has 45 units of power left
# Bus 8 have still 33 minutes to drive
# Bus 3 starts route 2
# Bus 5 fastly charging => 46/100
# Bus 7 fastly charging => 29/100
# Time is now 297
# Battery from bus 1 has 10 units of power left
# Bus 1 have still 9 minutes to drive
# Battery from bus 2 has 14 units of power left
# Bus 2 have still 2 minutes to drive
# Battery from bus 3 has 60 units of power left
# Bus 3 have still 59 minutes to drive
# Battery from bus 4 has 24 units of power left
# Bus 4 have still 12 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 34 units of power left
# Bus 6 have still 22 minutes to drive
# Bus 7 waiting at the station
# Battery from bus 8 has 44 units of power left
# Bus 8 have still 32 minutes to drive
# Bus 5 fastly charging => 47/100
# Bus 7 fastly charging => 30/100
# Time is now 298
# Battery from bus 1 has 9 units of power left
# Bus 1 have still 8 minutes to drive
# Battery from bus 2 has 13 units of power left
# Bus 2 have still 1 minutes to drive
# Battery from bus 3 has 59 units of power left
# Bus 3 have still 58 minutes to drive
# Battery from bus 4 has 23 units of power left
# Bus 4 have still 11 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 33 units of power left
# Bus 6 have still 21 minutes to drive
# Bus 7 waiting at the station
# Battery from bus 8 has 43 units of power left
# Bus 8 have still 31 minutes to drive
# Bus 5 fastly charging => 49/100
# Bus 7 fastly charging => 32/100
# Time is now 299
# Battery from bus 1 has 8 units of power left
# Bus 1 have still 7 minutes to drive
# Battery from bus 2 has 12 units of power left
# Bus 2 have still 0 minutes to drive
# Bus 2 is done, it is now at the station
# Battery from bus 3 has 58 units of power left
# Bus 3 have still 57 minutes to drive
# Battery from bus 4 has 22 units of power left
# Bus 4 have still 10 minutes to drive
# Bus 5 waiting at the station
# Battery from bus 6 has 32 units of power left
# Bus 6 have still 20 minutes to drive
# Bus 7 waiting at the station
# Battery from bus 8 has 42 units of power left
# Bus 8 have still 30 minutes to drive
# Bus 5 starts route 1
# Bus 7 fastly charging => 34/100
# Bus 2 fastly charging => 14/100
# Time is now 300
# Battery from bus 1 has 7 units of power left
# Bus 1 have still 6 minutes to drive
# Bus 2 waiting at the station
# Battery from bus 3 has 57 units of power left
# Bus 3 have still 56 minutes to drive
# Battery from bus 4 has 21 units of power left
# Bus 4 have still 9 minutes to drive
# Battery from bus 5 has 48 units of power left
# Bus 5 have still 39 minutes to drive
# Battery from bus 6 has 31 units of power left
# Bus 6 have still 19 minutes to drive
# Bus 7 waiting at the station
# Battery from bus 8 has 41 units of power left
# Bus 8 have still 29 minutes to drive
# Bus 7 fastly charging => 36/100
# Bus 2 fastly charging => 16/100
